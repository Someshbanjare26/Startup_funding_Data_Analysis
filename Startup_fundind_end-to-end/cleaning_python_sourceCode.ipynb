# %%
import pandas as pd
import numpy as np

# %%
df_old = pd.read_csv("startup_funding(2000-2023).csv")
df_new = pd.read_csv("startup_funding(2020-2025)sample.csv")

# %%
df_old.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1  Susquehanna Growth Equity              Series C     80,48,394     NaN
# 2      Sequoia Capital India              Series B   1,83,58,860     NaN
# 3             Vinod Khatumal          Pre-series A     30,00,000     NaN
# 4    Sprout Venture Partners            Seed Round     18,00,000     NaN

# %%
df_new.head()
# Out:
#     Startup              Industry   SubVertical       City  \
# 0  Housejoy                EdTech           K12     Mumbai
# 1     Groww                 Media     Streaming  Bengaluru
# 2     Groww              Mobility  Ride Sharing  Hyderabad
# 3   FarmBox  Consumer Electronics     Wearables   Gurugram
# 4     Udaan            RealEstate   Rental Tech     Mumbai
#
#                          Investors InvestmentType  InvestmentAmount_USD  \
# 0                 Lightspeed India           Seed                199000
# 1                              IFC           Seed               1668000
# 2  Nexus Venture Partners, Peak XV       Series B              38052000
# 3    Kalaari Capital, Y Combinator           Seed                455000
# 4        Bessemer Venture Partners           Seed                 89000
#
#          Date
# 0  19-04-2023
# 1  28-01-2025
# 2  14-03-2021
# 3  11-09-2023
# 4  31-01-2024

# %%
print("Old dataset shape:", df_old.shape)
print("New dataset shape:", df_new.shape)
# Out:
# Old dataset shape: (3044, 10)
# New dataset shape: (1100, 8)

# %%
df_old.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df_new.columns
# Out:
# Index(['Startup', 'Industry', 'SubVertical', 'City', 'Investors',
#        'InvestmentType', 'InvestmentAmount_USD', 'Date'],
#       dtype='object')

# %%
df_old.columns = df_old.columns.str.lower().str.strip()
df_new.columns = df_new.columns.str.lower().str.strip()

# %%
df_old.columns
# Out:
# Index(['sr no', 'date dd/mm/yyyy', 'startup name', 'industry vertical',
#        'subvertical', 'city  location', 'investors name', 'investmentntype',
#        'amount in usd', 'remarks'],
#       dtype='object')

# %%
df_new.columns
# Out:
# Index(['startup', 'industry', 'subvertical', 'city', 'investors',
#        'investmenttype', 'investmentamount_usd', 'date'],
#       dtype='object')

# %%
df_old = df_old.rename(columns={
    'startup name': 'startup_name',
    'city location': 'city',
    'industry vertical': 'industry',
    'subvertical': 'sub_industry',
    'investors name': 'investors',
    'investmentntype': 'funding_round',
    'amount in usd': 'funding_amount_usd',
    'date dd/mm/yyyy': 'date'
})

# %%
df_new = df_new.rename(columns={
    'startup': 'startup_name',
    'industry': 'industry',
    'subvertical': 'sub_industry',
    'investors': 'investors',
    'investmenttype': 'funding_round',
    'investmentamount_usd': 'funding_amount_usd',
    'date': 'date'
})

# %%
df_old.columns = (
    df_old.columns
    .str.strip()       
    .str.replace(r'\s+', ' ', regex=True)  
)

# %%
list(df_old.columns)
# Out:
# ['sr no',
#  'date',
#  'startup_name',
#  'industry',
#  'sub_industry',
#  'city location',
#  'investors',
#  'funding_round',
#  'funding_amount_usd',
#  'remarks',
#  'data_source']

# %%
df_old = df_old.rename(columns={
    'city location': 'city'
})

# %%
df_old.columns
# Out:
# Index(['sr no', 'date', 'startup_name', 'industry', 'sub_industry', 'city',
#        'investors', 'funding_round', 'funding_amount_usd', 'remarks',
#        'data_source'],
#       dtype='object')

# %%
df_new.columns
# Out:
# Index(['startup_name', 'industry', 'sub_industry', 'city', 'investors',
#        'funding_round', 'funding_amount_usd', 'date', 'data_source'],
#       dtype='object')

# %%
df_old['data_source'] = '2000_2023'
df_new['data_source'] = '2020_2025'

# %%
df_old['date'] = pd.to_datetime(df_old['date'], errors='coerce', dayfirst=True)
df_new['date'] = pd.to_datetime(df_new['date'], errors='coerce', dayfirst=True)

# %%
df_old['date'].isna().sum()
df_new['date'].isna().sum()
# Out:
# np.int64(0)

# %%
def clean_amount(x):
    if pd.isna(x):
        return np.nan
    x = str(x).replace(',', '').replace('$', '').replace('₹', '')
    return pd.to_numeric(x, errors='coerce')

df_old['funding_amount_usd'] = df_old['funding_amount_usd'].apply(clean_amount)
df_new['funding_amount_usd'] = df_new['funding_amount_usd'].apply(clean_amount)

# %%
df_old['funding_amount_usd'].describe()
# Out:
# count    2.065000e+03
# mean     1.842990e+07
# std      1.213734e+08
# min      1.600000e+04
# 25%      4.700000e+05
# 50%      1.700000e+06
# 75%      8.000000e+06
# max      3.900000e+09
# Name: funding_amount_usd, dtype: float64

# %%
df_old.columns
# Out:
# Index(['sr no', 'date', 'startup_name', 'industry', 'sub_industry', 'city',
#        'investors', 'funding_round', 'funding_amount_usd', 'remarks',
#        'data_source'],
#       dtype='object')

# %%
df_old.columns
# Out:
# Index(['sr no', 'date', 'startup_name', 'industry', 'sub_industry', 'city',
#        'investors', 'funding_round', 'funding_amount_usd', 'remarks',
#        'data_source'],
#       dtype='object')

# %%
cols = [
    'startup_name',
    'industry',
    'sub_industry',
    'city',
    'investors',
    'funding_round',
    'funding_amount_usd',
    'date',
    'data_source'
]

df_old = df_old[cols]
df_new = df_new[cols]

# %%
df_old.head()
# Out:
#                    startup_name             industry  \
# 0                        BYJU’S               E-Tech
# 1                        Shuttl       Transportation
# 2                     Mamaearth           E-commerce
# 3  https://www.wealthbucket.in/              FinTech
# 4                        Fashor  Fashion and Apparel
#
#                             sub_industry       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors         funding_round  funding_amount_usd  \
# 0    Tiger Global Management  Private Equity Round         200000000.0
# 1  Susquehanna Growth Equity              Series C           8048394.0
# 2      Sequoia Capital India              Series B          18358860.0
# 3             Vinod Khatumal          Pre-series A           3000000.0
# 4    Sprout Venture Partners            Seed Round           1800000.0
#
#         date data_source
# 0 2020-01-09   2000_2023
# 1 2020-01-13   2000_2023
# 2 2020-01-09   2000_2023
# 3 2020-01-02   2000_2023
# 4 2020-01-02   2000_2023

# %%
df = pd.concat([df_old, df_new], ignore_index=True)

# %%
df.shape
# Out:
# (4144, 9)

# %%
before = df.shape[0]

df = df.drop_duplicates(
    subset=['startup_name', 'date', 'funding_amount_usd']
)

after = df.shape[0]

print("Duplicates removed:", before - after)
# Out:
# Duplicates removed: 0

# %%
df['city'] = df['city'].fillna('Unknown')
df['industry'] = df['industry'].fillna('Unknown')
df['sub_industry'] = df['sub_industry'].fillna('Unknown')
df['funding_round'] = df['funding_round'].fillna('Undisclosed')

# %%
df.isna().sum()
# Out:
# startup_name            0
# industry                0
# sub_industry            0
# city                    0
# investors              24
# funding_round           0
# funding_amount_usd    979
# date                    8
# data_source             0
# dtype: int64

# %%
df['year'] = df['date'].dt.year

# %%
df[['date', 'year']].head()
# Out:
#         date    year
# 0 2020-01-09  2020.0
# 1 2020-01-13  2020.0
# 2 2020-01-09  2020.0
# 3 2020-01-02  2020.0
# 4 2020-01-02  2020.0

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4144 entries, 0 to 4143
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   startup_name        4144 non-null   object
#  1   industry            4144 non-null   object
#  2   sub_industry        4144 non-null   object
#  3   city                4144 non-null   object
#  4   investors           4120 non-null   object
#  5   funding_round       4144 non-null   object
#  6   funding_amount_usd  3165 non-null   float64
#  7   date                4136 non-null   datetime64[ns]
#  8   data_source         4144 non-null   object
#  9   year                4136 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 323.9+ KB
#                    startup_name             industry  \
# 0                        BYJU’S               E-Tech
# 1                        Shuttl       Transportation
# 2                     Mamaearth           E-commerce
# 3  https://www.wealthbucket.in/              FinTech
# 4                        Fashor  Fashion and Apparel
#
#                             sub_industry       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors         funding_round  funding_amount_usd  \
# 0    Tiger Global Management  Private Equity Round         200000000.0
# 1  Susquehanna Growth Equity              Series C           8048394.0
# 2      Sequoia Capital India              Series B          18358860.0
# 3             Vinod Khatumal          Pre-series A           3000000.0
# 4    Sprout Venture Partners            Seed Round           1800000.0
#
#         date data_source    year
# 0 2020-01-09   2000_2023  2020.0
# 1 2020-01-13   2000_2023  2020.0
# 2 2020-01-09   2000_2023  2020.0
# 3 2020-01-02   2000_2023  2020.0
# 4 2020-01-02   2000_2023  2020.0

# %%
df[df['startup_name'].str.contains('http', case=False, na=False)]
# Out:
#                    startup_name industry       sub_industry       city  \
# 3  https://www.wealthbucket.in/  FinTech  Online Investment  New Delhi
#
#         investors funding_round  funding_amount_usd       date data_source  \
# 3  Vinod Khatumal  Pre-series A           3000000.0 2020-01-02   2000_2023
#
#      year
# 3  2020.0

# %%
df['startup_name'] = (
    df['startup_name']
    .str.replace(r'https?://(www\.)?', '', regex=True)
    .str.replace(r'\.in|\.com|/', '', regex=True)
    .str.strip()
    .str.title()
)

# %%
df[['startup_name']].head(10)
# Out:
#    startup_name
# 0        Byju’S
# 1        Shuttl
# 2     Mamaearth
# 3  Wealthbucket
# 4        Fashor
# 5         Pando
# 6        Zomato
# 7        Ecozen
# 8      Cardekho
# 9  Dhruva Space

# %%
df['was_url'] = df['startup_name'].str.contains('http', case=False, na=False)

# %%
df['was_url'].value_counts()
# Out:
# was_url
# False    4144
# Name: count, dtype: int64

# %%
df.to_csv("clean_startup_funding_2000_2025.csv", index=False)
